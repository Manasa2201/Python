# %%
# Interview Questions
# 1. python is pure object oriented programming language or not?
# python is not pure object oriented language..but not pure.java is pure oop.c is procedure oriented language.
# 2. python is case sensitive or not?
# yes
# 3. python is complier or interpreter?
# interpreterd language ..complier means high level to low level
# source code
#complier
#byte code(intermediate code)
#pvm(interpreter)
#machine code
# 4. python is platform independent language.
# Yes due to pvm
# 5. In which language pythoon is develop?
# c python:developed in c language
# j python:developed in java language
# PyPy: developed in python
#micro python : chip programming and used in IOT
# 6.which is fastest language out of C,C++,java,python?
# C is  fastest , python is slowest beacuse of c is converting assessmbly language...

# %%
# Python for interview prepration...
# python developer, data engineer, data analyst,ML,DL,GEN AI
#python history in 1991
#print is a func or processor or function language
# hacker Rank,Greeksforgreeks,
print("Hello World")
# Out:
# Hello World

# %%
#Variables in python variables are containers to store value or data..
# type is func
a = 10
b = "MANASA"
c = 20.5
d = True
e = None

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))


# rules
# Dont start with number..start with letters and underscore
# spl symbols are not allowed
# must be case senstitive
# space is also not allowed.
# how to del the varable
var=100
print(var)
a="Hello"
b=5
a,b=b,a
print(a,b)

# swap two numbers using XOR
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>
# 100
# 5 Hello
